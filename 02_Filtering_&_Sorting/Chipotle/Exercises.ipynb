# %% [markdown]
# # Ex1 - Filtering and Sorting Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("../../#/chipotle.tsv", sep="\t")
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ### Step 4. How many products cost more than $10.00?

# %%
func_price = lambda x: round(float(x.replace("$","")))
chipo["price"] = chipo["item_price"].apply(func_price)
chipo[chipo["price"] > 10]["item_name"].value_counts().count()
# Out:
# 31

# %% [markdown]
# ### Step 5. What is the price of each item?
# ###### print a data frame with only two columns item_name and item_price

# %%
df = chipo[chipo["price"] > 10]
df = df[["item_name","item_price"]].drop_duplicates()
df
# Out:
#                  item_name item_price
# 4             Chicken Bowl    $16.98
# 5             Chicken Bowl    $10.98
# 7            Steak Burrito    $11.75
# 13            Chicken Bowl    $11.25
# 23         Chicken Burrito    $10.98
# ...                    ...        ...
# 3891  Chicken Crispy Tacos    $16.98
# 4152         Bottled Water    $15.00
# 4354      Steak Soft Tacos    $18.50
# 4489   Chips and Guacamole    $17.80
# 4510         Barbacoa Bowl    $11.49
#
# [96 rows x 2 columns]

# %% [markdown]
# ### Step 6. Sort by the name of the item

# %%
df.sort_values("item_name")
# Out:
#               item_name item_price
# 3389  6 Pack Soft Drink    $12.98
# 4510      Barbacoa Bowl    $11.49
# 39        Barbacoa Bowl    $11.75
# 471       Barbacoa Bowl    $11.48
# 3276   Barbacoa Burrito    $11.48
# ...                 ...        ...
# 57       Veggie Burrito    $11.25
# 435      Veggie Burrito    $10.98
# 186   Veggie Salad Bowl    $11.25
# 738   Veggie Soft Tacos    $11.25
# 3889  Veggie Soft Tacos    $16.98
#
# [96 rows x 2 columns]

# %% [markdown]
# ### Step 7. What was the quantity of the most expensive item ordered?

# %%
chipo.head()
chipo.groupby(by=["price"]).sum("quantity").sort_values("quantity", ascending=False).iloc[0]
# Out:
# order_id    1322595
# quantity       1450
# Name: 9, dtype: int64

# %% [markdown]
# ### Step 8. How many times was a Veggie Salad Bowl ordered?

# %%
chipo[chipo["item_name"]=="Veggie Salad Bowl"].count().order_id
# Out:
# 18

# %% [markdown]
# ### Step 9. How many times did someone order more than one Canned Soda?

# %%
soda = chipo[chipo["item_name"]=="Veggie Salad Bowl"].count().order_id
others = chipo.groupby(by=["item_name"]).count()
others["frec"] = others["order_id"] - soda
others[others["frec"]>0]
# Out:
#                                        order_id  quantity  choice_description  \
# item_name
# 6 Pack Soft Drink                            54        54                  54
# Barbacoa Bowl                                66        66                  66
# Barbacoa Burrito                             91        91                  91
# Barbacoa Soft Tacos                          25        25                  25
# Bottled Water                               162       162                   0
# Canned Soda                                 104       104                 104
# Canned Soft Drink                           301       301                 301
# Carnitas Bowl                                68        68                  68
# Carnitas Burrito                             59        59                  59
# Carnitas Soft Tacos                          40        40                  40
# Chicken Bowl                                726       726                 726
# ...

# %%
soda
# Out:
# 18
